# %%
import pandas as pd

# %%
# 데이터 불러오기
df = pd.read_csv('C:/Users/Bang/Desktop/머신러닝/서울특별시 코로나19 자치구별 확진자 발생동향.csv')
    # 파일 경로 표시 : / or \\로 해야한다. \로 표시하면 에러
df2 = pd.read_csv('C:/Users/Bang/Desktop/머신러닝/서울특별시_만5세 이하 코로나19 확진자 현황_20220131.csv')
print(df)
print(df2)
# Out:
#       ��ġ�� ������  ���α� ��ü  ���α� �߰�  �߱� ��ü  �߱� �߰�  ��걸 ��ü  ��걸 �߰�  \
# 0    2022.03.19.00      27391       1061    24821      912    41106     1740
# 1    2022.03.18.00      26330       1172    23909      977    39366     2045
# 2    2022.03.17.00      25158       1826    22932     1761    37321     3283
# 3    2022.03.16.00      23332       1570    21168     1176    34034     1048
# 4    2022.03.15.00      21762        582    19992      801    32986     1195
# ..             ...        ...        ...      ...      ...      ...      ...
# 770    20.02.09.10          0          0        0        0        0        0
# 771    20.02.08.10          0          0        0        0        0        0
# 772    20.02.07.10          0          0        0        0        0        0
# 773    20.02.06.10          3          0        0        0        0        0
# 774    20.02.05.10          3          0        0        0        0        0
#
# ...

# %%
# numpy 변환
df = df.to_numpy()
df2 = df2.to_numpy()
print(df)
print(df2)
# Out:
# [['2022.03.19.00' 27391 1061 ... 2955 123665 5168]
#  ['2022.03.18.00' 26330 1172 ... 3628 118497 4769]
#  ['2022.03.17.00' 25158 1826 ... 4390 113728 7310]
#  ...
#  ['20.02.07.10' 0 0 ... 0 0 0]
#  ['20.02.06.10' 3 0 ... 0 2 1]
#  ['20.02.05.10' 3 0 ... 0 1 0]]
# [['2021-03-01' 6]
#  ['2021-03-02' 7]
#  ['2021-03-03' 2]
#  ['2021-03-04' 1]
#  ['2021-03-05' 1]
#  ['2021-03-06' 2]
#  ['2021-03-07' 3]
#  ['2021-03-08' 3]
#  ['2021-03-09' 4]
#  ['2021-03-10' 4]
#  ['2021-03-11' 4]
#  ['2021-03-12' 2]
#  ['2021-03-13' 3]
#  ['2021-03-14' 6]
#  ['2021-03-15' 7]
#  ['2021-03-16' 1]
#  ['2021-03-17' 4]
#  ['2021-03-18' 2]
#  ['2021-03-19' 4]
#  ['2021-03-20' 2]
#  ['2021-03-21' 4]
#  ['2021-03-22' 3]
#  ['2021-03-23' 3]
#  ['2021-03-24' 3]
#  ['2021-03-25' 5]
#  ['2021-03-26' 5]
#  ['2021-03-27' 4]
#  ['2021-03-28' 1]
#  ['2021-03-29' 5]
#  ['2021-03-30' 6]
#  ['2021-03-31' 5]
#  ['2021-04-02' 4]
#  ['2021-04-03' 2]
#  ['2021-04-04' 3]
#  ['2021-04-05' 3]
#  ['2021-04-06' 4]
# ...

# %%
allcor_num = df.iloc[1:, 1]
# fivecor_num = df2.iloc[1:, 1]
print(allcor_num)
# print(fivecor_num)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-e6a781a7999b> in <module>
# ----> 1 allcor_num = df.iloc[1:, 1]
#       2 # fivecor_num = df2.iloc[1:, 1]
#       3 print(allcor_num)
#       4 # print(fivecor_num)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
from sklearn.model_
